# %% [markdown]
# <a href="https://colab.research.google.com/github/Misael-GC/hyperblog-1/blob/master/demo/vibevoice_realtime_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # VibeVoice-Realtime Colab — T4 Quickstart

# %% [markdown]
# ## Step 1: Setup Environment

# %%
# Check for T4 GPU
import torch
if torch.cuda.is_available() and "T4" in torch.cuda.get_device_name(0):
    print("✅ T4 GPU detected")
else:
    print("""
    ⚠️ WARNING: T4 GPU not detected

    The recommended runtime for this Colab notebook is "T4 GPU".

    To change the runtime type:

        1. Click on "Runtime" in the top navigation menu
        2. Click on "Change runtime type"
        3. Select "T4 GPU"
        4. Click "OK" if a "Disconnect and delete runtime" window appears
        5. Click on "Save"

    """)

# Clone the VibeVoice repository
![ -d /content/VibeVoice ] || git clone --quiet --branch main --depth 1 https://github.com/microsoft/VibeVoice.git /content/VibeVoice
print("✅ Cloned VibeVoice repository")

# Install project dependencies
# !uv pip --quiet install --system -e /content/VibeVoice
# !wget -q https://github.com/cloudflare/cloudflared/releases/latest/download/cloudflared-linux-amd64 -O cloudflared && chmod +x cloudflared
print("✅ Installed dependencies")

# Download model
from huggingface_hub import snapshot_download
snapshot_download("microsoft/VibeVoice-Realtime-0.5B", local_dir="/content/models/VibeVoice-Realtime-0.5B")
print("✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B")
# Out:
# ✅ T4 GPU detected
# ✅ Cloned VibeVoice repository
# ✅ Installed dependencies
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# config.json: 0.00B [00:00, ?B/s]
# .gitattributes: 0.00B [00:00, ?B/s]
# preprocessor_config.json:   0%|          | 0.00/360 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# figures/Fig1.png:   0%|          | 0.00/124k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/2.04G [00:00<?, ?B/s]
# ✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B

# %% [markdown]
# [Optional] If the download exceeds 1 minute, it is probably stuck. You can: (1) interrupt the execution, (2) log in to Hugging Face, and (3) try download again.

# %%
from huggingface_hub import login
login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
snapshot_download("microsoft/VibeVoice-Realtime-0.5B", local_dir="/content/models/VibeVoice-Realtime-0.5B")
print("✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B")
# Out:
# Fetching 6 files:   0%|          | 0/6 [00:00<?, ?it/s]
# ✅ Downloaded model: microsoft/VibeVoice-Realtime-0.5B

# %% [markdown]
# ## Step 2: Launch VibeVoice-Realtime Demo

# %%
import subprocess, re, time, threading

srv = subprocess.Popen(
    "python /content/VibeVoice/demo/vibevoice_realtime_demo.py --model_path /content/models/VibeVoice-Realtime-0.5B --port 8000",
    shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True,
)
cf = subprocess.Popen(
    "./cloudflared tunnel --url http://localhost:8000 --no-autoupdate",
    shell=True, stdout=subprocess.PIPE, stderr=subprocess.STDOUT, text=True, bufsize=1, universal_newlines=True,
)

public_url = None
server_ready = False
url_pattern  = re.compile(r"(https://[a-z0-9-]+\.trycloudflare\.com)")

def read_srv():
    global server_ready
    for ln in srv.stdout:
        print(ln.strip())
        if "Uvicorn running on" in ln:
            server_ready = True

def read_cf():
    global public_url
    for ln in cf.stdout:
        m = url_pattern.search(ln)
        if m:
            public_url = m.group(1)
            break

threading.Thread(target=read_srv, daemon=True).start()
threading.Thread(target=read_cf,  daemon=True).start()


while True:
    if server_ready and public_url:
        print(f"✅ Public URL: {public_url}\n");
        public_url = None
    time.sleep(0.25)
# Out:
# 2025-12-10 02:37:10.143973: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765334230.162993    2106 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765334230.169123    2106 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1765334230.183668    2106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765334230.183688    2106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765334230.183691    2106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1765334230.183695    2106 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-10 02:37:10.188614: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING:vibevoice.modular.modular_vibevoice_tokenizer:APEX FusedRMSNorm not available, using native implementation
# INFO:     Started server process [2106]
# INFO:     Waiting for application startup.
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'Qwen2Tokenizer'.
# The class this function is called from is 'VibeVoiceTextTokenizerFast'.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://0.0.0.0:8000 (Press CTRL+C to quit)
# ✅ Public URL: https://officials-preparation-das-pharmacies.trycloudflare.com
#
# [startup] Loading processor from /content/models/VibeVoice-Realtime-0.5B
# Using device: cuda, torch_dtype: torch.bfloat16, attn_implementation: flash_attention_2
# Error loading the model. Trying to use SDPA. However, note that only flash_attention_2 has been fully tested, and using SDPA may result in lower audio quality.
# Load model with SDPA successfully
# [startup] Found 25 voice presets
# [startup] Using fallback voice preset: de-Spk0_man
# [startup] Loading voice preset de-Spk0_man from /content/VibeVoice/demo/voices/streaming_model/de-Spk0_man.pt
# [startup] Loading prefilled prompt from /content/VibeVoice/demo/voices/streaming_model/de-Spk0_man.pt
# [startup] Model ready.
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "GET / HTTP/1.1" 200 OK
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "GET /config HTTP/1.1" 200 OK
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "WebSocket /stream?text=Enter+your+text+here+and+click+%22Start%22+to+instantly+hear+the+VibeVoice-Realtime+TTS+output+audio.&cfg=1.500&steps=5&voice=sp-Spk0_woman" [accepted]
# INFO:     connection open
# Client connected, text='Enter your text here and click "Start" to instantly hear the VibeVoice-Realtime TTS output audio.'
# [startup] Loading voice preset sp-Spk0_woman from /content/VibeVoice/demo/voices/streaming_model/sp-Spk0_woman.pt
# [startup] Loading prefilled prompt from /content/VibeVoice/demo/voices/streaming_model/sp-Spk0_woman.pt
#
# Prefilled 314 tokens, current step (314 / 8192):   4%|▍         | 314/8192 [00:00<?, ?it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (319 / 8192):   4%|▍         | 319/8192 [00:00<00:00, 16070.13it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (319 / 8192):   4%|▍         | 320/8192 [00:01<23:50,  5.50it/s]
# Prefilled 5 text tokens, generated 1 speech tokens, current step (320 / 8192):   4%|▍         | 320/8192 [00:01<23:50,  5.50it/s]
# Prefilled 5 text tokens, generated 1 speech tokens, current step (320 / 8192):   4%|▍         | 321/8192 [00:01<24:20,  5.39it/s]
# Prefilled 5 text tokens, generated 2 speech tokens, current step (321 / 8192):   4%|▍         | 321/8192 [00:01<24:20,  5.39it/s]INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "GET /favicon.ico HTTP/1.1" 404 Not Found
#
# Prefilled 5 text tokens, generated 2 speech tokens, current step (321 / 8192):   4%|▍         | 322/8192 [00:01<22:44,  5.77it/s]
# Prefilled 5 text tokens, generated 3 speech tokens, current step (322 / 8192):   4%|▍         | 322/8192 [00:01<22:44,  5.77it/s]
# Prefilled 5 text tokens, generated 3 speech tokens, current step (322 / 8192):   4%|▍         | 323/8192 [00:01<21:20,  6.15it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (323 / 8192):   4%|▍         | 323/8192 [00:01<21:20,  6.15it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (323 / 8192):   4%|▍         | 324/8192 [00:01<19:38,  6.67it/s]
# Prefilled 5 text tokens, generated 5 speech tokens, current step (324 / 8192):   4%|▍         | 324/8192 [00:01<19:38,  6.67it/s]
# Prefilled 5 text tokens, generated 5 speech tokens, current step (324 / 8192):   4%|▍         | 325/8192 [00:01<18:17,  7.17it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (325 / 8192):   4%|▍         | 325/8192 [00:01<18:17,  7.17it/s]
# Prefilled 10 text tokens, generated 6 speech tokens, current step (330 / 8192):   4%|▍         | 330/8192 [00:01<18:16,  7.17it/s]
# Prefilled 10 text tokens, generated 6 speech tokens, current step (330 / 8192):   4%|▍         | 331/8192 [00:01<07:50, 16.70it/s]
# Prefilled 10 text tokens, generated 7 speech tokens, current step (331 / 8192):   4%|▍         | 331/8192 [00:01<07:50, 16.70it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (332 / 8192):   4%|▍         | 332/8192 [00:02<07:50, 16.70it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (332 / 8192):   4%|▍         | 333/8192 [00:02<09:42, 13.49it/s]
# Prefilled 10 text tokens, generated 9 speech tokens, current step (333 / 8192):   4%|▍         | 333/8192 [00:02<09:42, 13.49it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (334 / 8192):   4%|▍         | 334/8192 [00:02<09:42, 13.49it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (334 / 8192):   4%|▍         | 335/8192 [00:02<10:39, 12.28it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (335 / 8192):   4%|▍         | 335/8192 [00:02<10:39, 12.28it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (336 / 8192):   4%|▍         | 336/8192 [00:02<10:39, 12.28it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (336 / 8192):   4%|▍         | 341/8192 [00:02<06:57, 18.79it/s]
# Prefilled 15 text tokens, generated 12 speech tokens, current step (341 / 8192):   4%|▍         | 341/8192 [00:02<06:57, 18.79it/s]
# Prefilled 15 text tokens, generated 13 speech tokens, current step (342 / 8192):   4%|▍         | 342/8192 [00:02<06:57, 18.79it/s]
# Prefilled 15 text tokens, generated 14 speech tokens, current step (343 / 8192):   4%|▍         | 343/8192 [00:02<06:57, 18.79it/s]
# Prefilled 15 text tokens, generated 14 speech tokens, current step (343 / 8192):   4%|▍         | 344/8192 [00:02<08:32, 15.30it/s]
# Prefilled 15 text tokens, generated 15 speech tokens, current step (344 / 8192):   4%|▍         | 344/8192 [00:02<08:32, 15.30it/s]
# Prefilled 15 text tokens, generated 16 speech tokens, current step (345 / 8192):   4%|▍         | 345/8192 [00:02<08:32, 15.30it/s]
# Prefilled 15 text tokens, generated 16 speech tokens, current step (345 / 8192):   4%|▍         | 346/8192 [00:03<09:39, 13.53it/s]
# Prefilled 15 text tokens, generated 17 speech tokens, current step (346 / 8192):   4%|▍         | 346/8192 [00:03<09:39, 13.53it/s]
# Prefilled 15 text tokens, generated 18 speech tokens, current step (347 / 8192):   4%|▍         | 347/8192 [00:03<09:39, 13.53it/s]
# Prefilled 15 text tokens, generated 18 speech tokens, current step (347 / 8192):   4%|▍         | 352/8192 [00:03<06:47, 19.22it/s]
# Prefilled 20 text tokens, generated 18 speech tokens, current step (352 / 8192):   4%|▍         | 352/8192 [00:03<06:47, 19.22it/s]
# Prefilled 20 text tokens, generated 19 speech tokens, current step (353 / 8192):   4%|▍         | 353/8192 [00:03<06:47, 19.22it/s]
# Prefilled 20 text tokens, generated 20 speech tokens, current step (354 / 8192):   4%|▍         | 354/8192 [00:03<06:47, 19.22it/s]
# Prefilled 20 text tokens, generated 20 speech tokens, current step (354 / 8192):   4%|▍         | 355/8192 [00:03<08:16, 15.78it/s]
# Prefilled 20 text tokens, generated 21 speech tokens, current step (355 / 8192):   4%|▍         | 355/8192 [00:03<08:16, 15.78it/s]
# Prefilled 20 text tokens, generated 22 speech tokens, current step (356 / 8192):   4%|▍         | 356/8192 [00:03<08:16, 15.78it/s]
# Prefilled 20 text tokens, generated 22 speech tokens, current step (356 / 8192):   4%|▍         | 357/8192 [00:03<09:22, 13.93it/s]
# Prefilled 20 text tokens, generated 23 speech tokens, current step (357 / 8192):   4%|▍         | 357/8192 [00:03<09:22, 13.93it/s]
# Prefilled 20 text tokens, generated 24 speech tokens, current step (358 / 8192):   4%|▍         | 358/8192 [00:03<09:22, 13.93it/s]
# Prefilled 20 text tokens, generated 24 speech tokens, current step (358 / 8192):   4%|▍         | 362/8192 [00:03<07:14, 18.01it/s]
# Prefilled 24 text tokens, generated 24 speech tokens, current step (362 / 8192):   4%|▍         | 362/8192 [00:03<07:14, 18.01it/s]
# Prefilled 24 text tokens, generated 25 speech tokens, current step (363 / 8192):   4%|▍         | 363/8192 [00:03<07:14, 18.01it/s]
# Prefilled 24 text tokens, generated 26 speech tokens, current step (364 / 8192):   4%|▍         | 364/8192 [00:04<07:14, 18.01it/s]
# Prefilled 24 text tokens, generated 26 speech tokens, current step (364 / 8192):   4%|▍         | 365/8192 [00:04<08:39, 15.06it/s]
# Prefilled 24 text tokens, generated 27 speech tokens, current step (365 / 8192):   4%|▍         | 365/8192 [00:04<08:39, 15.06it/s]
# Prefilled 24 text tokens, generated 28 speech tokens, current step (366 / 8192):   4%|▍         | 366/8192 [00:04<08:39, 15.06it/s]
# Prefilled 24 text tokens, generated 28 speech tokens, current step (366 / 8192):   4%|▍         | 367/8192 [00:04<09:33, 13.64it/s]
# Prefilled 24 text tokens, generated 29 speech tokens, current step (367 / 8192):   4%|▍         | 367/8192 [00:04<09:33, 13.64it/s]
# Prefilled 24 text tokens, generated 30 speech tokens, current step (368 / 8192):   4%|▍         | 368/8192 [00:04<09:33, 13.64it/s]
# Prefilled 24 text tokens, generated 30 speech tokens, current step (368 / 8192):   5%|▍         | 369/8192 [00:04<10:25, 12.51it/s]
# Prefilled 24 text tokens, generated 31 speech tokens, current step (369 / 8192):   5%|▍         | 369/8192 [00:04<10:25, 12.51it/s]
# Prefilled 24 text tokens, generated 32 speech tokens, current step (370 / 8192):   5%|▍         | 370/8192 [00:04<10:25, 12.51it/s]
# Prefilled 24 text tokens, generated 32 speech tokens, current step (370 / 8192):   5%|▍         | 371/8192 [00:04<11:18, 11.53it/s]
# Prefilled 24 text tokens, generated 33 speech tokens, current step (371 / 8192):   5%|▍         | 371/8192 [00:04<11:18, 11.53it/s]
# Prefilled 24 text tokens, generated 34 speech tokens, current step (372 / 8192):   5%|▍         | 372/8192 [00:04<11:18, 11.53it/s]
# Prefilled 24 text tokens, generated 34 speech tokens, current step (372 / 8192):   5%|▍         | 373/8192 [00:04<11:53, 10.96it/s]
# Prefilled 24 text tokens, generated 35 speech tokens, current step (373 / 8192):   5%|▍         | 373/8192 [00:04<11:53, 10.96it/s]
# Prefilled 24 text tokens, generated 36 speech tokens, current step (374 / 8192):   5%|▍         | 374/8192 [00:05<11:53, 10.96it/s]
# Prefilled 24 text tokens, generated 36 speech tokens, current step (374 / 8192):   5%|▍         | 375/8192 [00:05<12:25, 10.49it/s]
# Prefilled 24 text tokens, generated 37 speech tokens, current step (375 / 8192):   5%|▍         | 375/8192 [00:05<12:25, 10.49it/s]
# Prefilled 24 text tokens, generated 38 speech tokens, current step (376 / 8192):   5%|▍         | 376/8192 [00:05<12:25, 10.49it/s]
# Prefilled 24 text tokens, generated 38 speech tokens, current step (376 / 8192):   5%|▍         | 377/8192 [00:05<12:39, 10.29it/s]
# Prefilled 24 text tokens, generated 39 speech tokens, current step (377 / 8192):   5%|▍         | 377/8192 [00:05<12:39, 10.29it/s]
# Prefilled 24 text tokens, generated 40 speech tokens, current step (378 / 8192):   5%|▍         | 378/8192 [00:05<12:39, 10.29it/s]
# Prefilled 24 text tokens, generated 40 speech tokens, current step (378 / 8192):   5%|▍         | 379/8192 [00:05<13:00, 10.01it/s]
# Prefilled 24 text tokens, generated 41 speech tokens, current step (379 / 8192):   5%|▍         | 379/8192 [00:05<13:00, 10.01it/s]
# Prefilled 24 text tokens, generated 42 speech tokens, current step (380 / 8192):   5%|▍         | 380/8192 [00:05<13:00, 10.01it/s]
# Prefilled 24 text tokens, generated 42 speech tokens, current step (380 / 8192):   5%|▍         | 381/8192 [00:05<13:08,  9.91it/s]
# Prefilled 24 text tokens, generated 43 speech tokens, current step (381 / 8192):   5%|▍         | 381/8192 [00:05<13:08,  9.91it/s]
# Prefilled 24 text tokens, generated 44 speech tokens, current step (382 / 8192):   5%|▍         | 382/8192 [00:05<13:08,  9.91it/s]
# Prefilled 24 text tokens, generated 44 speech tokens, current step (382 / 8192):   5%|▍         | 383/8192 [00:06<13:14,  9.83it/s]
# Prefilled 24 text tokens, generated 45 speech tokens, current step (383 / 8192):   5%|▍         | 383/8192 [00:06<13:14,  9.83it/s]
# Prefilled 24 text tokens, generated 45 speech tokens, current step (383 / 8192):   5%|▍         | 384/8192 [00:06<13:16,  9.80it/s]
# Prefilled 24 text tokens, generated 46 speech tokens, current step (384 / 8192):   5%|▍         | 384/8192 [00:06<13:16,  9.80it/s]
# Prefilled 24 text tokens, generated 46 speech tokens, current step (384 / 8192):   5%|▍         | 385/8192 [00:06<13:21,  9.74it/s]
# Prefilled 24 text tokens, generated 47 speech tokens, current step (385 / 8192):   5%|▍         | 385/8192 [00:06<13:21,  9.74it/s]
# Prefilled 24 text tokens, generated 47 speech tokens, current step (385 / 8192):   5%|▍         | 386/8192 [00:06<13:31,  9.62it/s]
# Prefilled 24 text tokens, generated 48 speech tokens, current step (386 / 8192):   5%|▍         | 386/8192 [00:06<13:31,  9.62it/s]
# Prefilled 24 text tokens, generated 48 speech tokens, current step (386 / 8192):   5%|▍         | 387/8192 [00:06<13:41,  9.50it/s]
# Prefilled 24 text tokens, generated 49 speech tokens, current step (387 / 8192):   5%|▍         | 387/8192 [00:06<13:41,  9.50it/s]
# Prefilled 24 text tokens, generated 49 speech tokens, current step (387 / 8192):   5%|▍         | 388/8192 [00:06<13:48,  9.42it/s]
# Prefilled 24 text tokens, generated 50 speech tokens, current step (388 / 8192):   5%|▍         | 388/8192 [00:06<13:48,  9.42it/s]
# Prefilled 24 text tokens, generated 50 speech tokens, current step (388 / 8192):   5%|▍         | 389/8192 [00:06<14:10,  9.17it/s]
# Prefilled 24 text tokens, generated 51 speech tokens, current step (389 / 8192):   5%|▍         | 389/8192 [00:06<14:10,  9.17it/s]
# Prefilled 24 text tokens, generated 51 speech tokens, current step (389 / 8192):   5%|▍         | 390/8192 [00:06<14:16,  9.11it/s]
# Prefilled 24 text tokens, generated 52 speech tokens, current step (390 / 8192):   5%|▍         | 390/8192 [00:06<14:16,  9.11it/s]
# Prefilled 24 text tokens, generated 52 speech tokens, current step (390 / 8192):   5%|▍         | 391/8192 [00:06<14:05,  9.22it/s]
# Prefilled 24 text tokens, generated 53 speech tokens, current step (391 / 8192):   5%|▍         | 391/8192 [00:06<14:05,  9.22it/s]
# Prefilled 24 text tokens, generated 53 speech tokens, current step (391 / 8192):   5%|▍         | 392/8192 [00:07<14:02,  9.26it/s]
# Prefilled 24 text tokens, generated 54 speech tokens, current step (392 / 8192):   5%|▍         | 392/8192 [00:07<14:02,  9.26it/s]
# Generation complete:   5%|▍         | 392/8192 [00:07<14:02,  9.26it/s]
#
# INFO:     connection closed
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "WebSocket /stream?text=Gorillaz+es+una+banda+de+musica+podemos+meter+IA+&cfg=1.500&steps=5&voice=sp-Spk0_woman" [accepted]
# INFO:     connection open
# WS handler exit
# Client connected, text='Gorillaz es una banda de musica podemos meter IA '
#
# Prefilled 314 tokens, current step (314 / 8192):   4%|▍         | 314/8192 [00:00<?, ?it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (319 / 8192):   4%|▍         | 319/8192 [00:00<00:00, 24995.85it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (319 / 8192):   4%|▍         | 320/8192 [00:00<03:31, 37.25it/s]
# Prefilled 5 text tokens, generated 1 speech tokens, current step (320 / 8192):   4%|▍         | 320/8192 [00:00<03:31, 37.25it/s]
# Prefilled 5 text tokens, generated 2 speech tokens, current step (321 / 8192):   4%|▍         | 321/8192 [00:00<03:31, 37.25it/s]
# Prefilled 5 text tokens, generated 3 speech tokens, current step (322 / 8192):   4%|▍         | 322/8192 [00:00<03:31, 37.25it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (323 / 8192):   4%|▍         | 323/8192 [00:00<03:31, 37.25it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (323 / 8192):   4%|▍         | 324/8192 [00:00<08:51, 14.80it/s]
# Prefilled 5 text tokens, generated 5 speech tokens, current step (324 / 8192):   4%|▍         | 324/8192 [00:00<08:51, 14.80it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (325 / 8192):   4%|▍         | 325/8192 [00:00<08:51, 14.80it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (325 / 8192):   4%|▍         | 330/8192 [00:00<06:06, 21.45it/s]
# Prefilled 10 text tokens, generated 6 speech tokens, current step (330 / 8192):   4%|▍         | 330/8192 [00:00<06:06, 21.45it/s]
# Prefilled 10 text tokens, generated 7 speech tokens, current step (331 / 8192):   4%|▍         | 331/8192 [00:00<06:06, 21.45it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (332 / 8192):   4%|▍         | 332/8192 [00:00<06:06, 21.45it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (332 / 8192):   4%|▍         | 333/8192 [00:01<07:52, 16.64it/s]
# Prefilled 10 text tokens, generated 9 speech tokens, current step (333 / 8192):   4%|▍         | 333/8192 [00:01<07:52, 16.64it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (334 / 8192):   4%|▍         | 334/8192 [00:01<07:52, 16.64it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (335 / 8192):   4%|▍         | 335/8192 [00:01<07:52, 16.64it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (335 / 8192):   4%|▍         | 336/8192 [00:01<09:30, 13.78it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (336 / 8192):   4%|▍         | 336/8192 [00:01<09:30, 13.78it/s]
# Prefilled 13 text tokens, generated 12 speech tokens, current step (339 / 8192):   4%|▍         | 339/8192 [00:01<09:29, 13.78it/s]
# Prefilled 13 text tokens, generated 12 speech tokens, current step (339 / 8192):   4%|▍         | 340/8192 [00:01<07:51, 16.66it/s]
# Prefilled 13 text tokens, generated 13 speech tokens, current step (340 / 8192):   4%|▍         | 340/8192 [00:01<07:51, 16.66it/s]
# Prefilled 13 text tokens, generated 14 speech tokens, current step (341 / 8192):   4%|▍         | 341/8192 [00:01<07:51, 16.66it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (342 / 8192):   4%|▍         | 342/8192 [00:01<07:51, 16.66it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (342 / 8192):   4%|▍         | 343/8192 [00:01<09:25, 13.89it/s]
# Prefilled 13 text tokens, generated 16 speech tokens, current step (343 / 8192):   4%|▍         | 343/8192 [00:01<09:25, 13.89it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (344 / 8192):   4%|▍         | 344/8192 [00:01<09:25, 13.89it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (344 / 8192):   4%|▍         | 345/8192 [00:02<10:14, 12.77it/s]
# Prefilled 13 text tokens, generated 18 speech tokens, current step (345 / 8192):   4%|▍         | 345/8192 [00:02<10:14, 12.77it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (346 / 8192):   4%|▍         | 346/8192 [00:02<10:14, 12.77it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (346 / 8192):   4%|▍         | 347/8192 [00:02<11:09, 11.72it/s]
# Prefilled 13 text tokens, generated 20 speech tokens, current step (347 / 8192):   4%|▍         | 347/8192 [00:02<11:09, 11.72it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (348 / 8192):   4%|▍         | 348/8192 [00:02<11:09, 11.72it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (348 / 8192):   4%|▍         | 349/8192 [00:02<11:43, 11.15it/s]
# Prefilled 13 text tokens, generated 22 speech tokens, current step (349 / 8192):   4%|▍         | 349/8192 [00:02<11:43, 11.15it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (350 / 8192):   4%|▍         | 350/8192 [00:02<11:43, 11.15it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (350 / 8192):   4%|▍         | 351/8192 [00:02<12:11, 10.71it/s]
# Prefilled 13 text tokens, generated 24 speech tokens, current step (351 / 8192):   4%|▍         | 351/8192 [00:02<12:11, 10.71it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (352 / 8192):   4%|▍         | 352/8192 [00:02<12:11, 10.71it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (352 / 8192):   4%|▍         | 353/8192 [00:02<12:30, 10.45it/s]
# Prefilled 13 text tokens, generated 26 speech tokens, current step (353 / 8192):   4%|▍         | 353/8192 [00:02<12:30, 10.45it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (354 / 8192):   4%|▍         | 354/8192 [00:02<12:29, 10.45it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (354 / 8192):   4%|▍         | 355/8192 [00:03<12:49, 10.19it/s]
# Prefilled 13 text tokens, generated 28 speech tokens, current step (355 / 8192):   4%|▍         | 355/8192 [00:03<12:49, 10.19it/s]
# Prefilled 13 text tokens, generated 29 speech tokens, current step (356 / 8192):   4%|▍         | 356/8192 [00:03<12:48, 10.19it/s]
# Prefilled 13 text tokens, generated 29 speech tokens, current step (356 / 8192):   4%|▍         | 357/8192 [00:03<13:04,  9.98it/s]
# Prefilled 13 text tokens, generated 30 speech tokens, current step (357 / 8192):   4%|▍         | 357/8192 [00:03<13:04,  9.98it/s]
#
# INFO:     connection closed
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "WebSocket /stream?text=Gorillaz+es+una+banda+de+musica+podemos+meter+IA+&cfg=1.500&steps=5&voice=sp-Spk1_man" [accepted]
# INFO:     connection open
# WS handler exit
# Client connected, text='Gorillaz es una banda de musica podemos meter IA '
# [startup] Loading voice preset sp-Spk1_man from /content/VibeVoice/demo/voices/streaming_model/sp-Spk1_man.pt
# [startup] Loading prefilled prompt from /content/VibeVoice/demo/voices/streaming_model/sp-Spk1_man.pt
#
# Prefilled 381 tokens, current step (381 / 8192):   5%|▍         | 381/8192 [00:00<?, ?it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (386 / 8192):   5%|▍         | 386/8192 [00:00<00:00, 32768.00it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (386 / 8192):   5%|▍         | 387/8192 [00:00<03:26, 37.72it/s]
# Prefilled 5 text tokens, generated 1 speech tokens, current step (387 / 8192):   5%|▍         | 387/8192 [00:00<03:26, 37.72it/s]
# Prefilled 5 text tokens, generated 2 speech tokens, current step (388 / 8192):   5%|▍         | 388/8192 [00:00<03:26, 37.72it/s]
# Prefilled 5 text tokens, generated 3 speech tokens, current step (389 / 8192):   5%|▍         | 389/8192 [00:00<03:26, 37.72it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (390 / 8192):   5%|▍         | 390/8192 [00:00<03:26, 37.72it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (390 / 8192):   5%|▍         | 391/8192 [00:00<08:48, 14.76it/s]
# Prefilled 5 text tokens, generated 5 speech tokens, current step (391 / 8192):   5%|▍         | 391/8192 [00:00<08:48, 14.76it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (392 / 8192):   5%|▍         | 392/8192 [00:00<08:48, 14.76it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (392 / 8192):   5%|▍         | 397/8192 [00:00<06:04, 21.37it/s]
# Prefilled 10 text tokens, generated 6 speech tokens, current step (397 / 8192):   5%|▍         | 397/8192 [00:00<06:04, 21.37it/s]
# Prefilled 10 text tokens, generated 7 speech tokens, current step (398 / 8192):   5%|▍         | 398/8192 [00:00<06:04, 21.37it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (399 / 8192):   5%|▍         | 399/8192 [00:00<06:04, 21.37it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (399 / 8192):   5%|▍         | 400/8192 [00:01<08:01, 16.18it/s]
# Prefilled 10 text tokens, generated 9 speech tokens, current step (400 / 8192):   5%|▍         | 400/8192 [00:01<08:01, 16.18it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (401 / 8192):   5%|▍         | 401/8192 [00:01<08:01, 16.18it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (402 / 8192):   5%|▍         | 402/8192 [00:01<08:01, 16.18it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (402 / 8192):   5%|▍         | 403/8192 [00:01<09:26, 13.76it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (403 / 8192):   5%|▍         | 403/8192 [00:01<09:26, 13.76it/s]
# Prefilled 13 text tokens, generated 12 speech tokens, current step (406 / 8192):   5%|▍         | 406/8192 [00:01<09:25, 13.76it/s]
# Prefilled 13 text tokens, generated 12 speech tokens, current step (406 / 8192):   5%|▍         | 407/8192 [00:01<07:47, 16.64it/s]
# Prefilled 13 text tokens, generated 13 speech tokens, current step (407 / 8192):   5%|▍         | 407/8192 [00:01<07:47, 16.64it/s]
# Prefilled 13 text tokens, generated 14 speech tokens, current step (408 / 8192):   5%|▍         | 408/8192 [00:01<07:47, 16.64it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (409 / 8192):   5%|▍         | 409/8192 [00:01<07:47, 16.64it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (409 / 8192):   5%|▌         | 410/8192 [00:01<09:18, 13.93it/s]
# Prefilled 13 text tokens, generated 16 speech tokens, current step (410 / 8192):   5%|▌         | 410/8192 [00:01<09:18, 13.93it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (411 / 8192):   5%|▌         | 411/8192 [00:01<09:18, 13.93it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (411 / 8192):   5%|▌         | 412/8192 [00:02<10:24, 12.47it/s]
# Prefilled 13 text tokens, generated 18 speech tokens, current step (412 / 8192):   5%|▌         | 412/8192 [00:02<10:24, 12.47it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (413 / 8192):   5%|▌         | 413/8192 [00:02<10:23, 12.47it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (413 / 8192):   5%|▌         | 414/8192 [00:02<11:00, 11.77it/s]
# Prefilled 13 text tokens, generated 20 speech tokens, current step (414 / 8192):   5%|▌         | 414/8192 [00:02<11:00, 11.77it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (415 / 8192):   5%|▌         | 415/8192 [00:02<11:00, 11.77it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (415 / 8192):   5%|▌         | 416/8192 [00:02<11:40, 11.10it/s]
# Prefilled 13 text tokens, generated 22 speech tokens, current step (416 / 8192):   5%|▌         | 416/8192 [00:02<11:40, 11.10it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (417 / 8192):   5%|▌         | 417/8192 [00:02<11:40, 11.10it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (417 / 8192):   5%|▌         | 418/8192 [00:02<12:07, 10.68it/s]
# Prefilled 13 text tokens, generated 24 speech tokens, current step (418 / 8192):   5%|▌         | 418/8192 [00:02<12:07, 10.68it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (419 / 8192):   5%|▌         | 419/8192 [00:02<12:07, 10.68it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (419 / 8192):   5%|▌         | 420/8192 [00:02<12:34, 10.30it/s]
# Prefilled 13 text tokens, generated 26 speech tokens, current step (420 / 8192):   5%|▌         | 420/8192 [00:02<12:34, 10.30it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (421 / 8192):   5%|▌         | 421/8192 [00:02<12:34, 10.30it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (421 / 8192):   5%|▌         | 422/8192 [00:03<13:00,  9.95it/s]
# Prefilled 13 text tokens, generated 28 speech tokens, current step (422 / 8192):   5%|▌         | 422/8192 [00:03<13:00,  9.95it/s]
# Prefilled 13 text tokens, generated 29 speech tokens, current step (423 / 8192):   5%|▌         | 423/8192 [00:03<13:00,  9.95it/s]
# Prefilled 13 text tokens, generated 29 speech tokens, current step (423 / 8192):   5%|▌         | 424/8192 [00:03<13:02,  9.93it/s]
# Prefilled 13 text tokens, generated 30 speech tokens, current step (424 / 8192):   5%|▌         | 424/8192 [00:03<13:02,  9.93it/s]
#
# INFO:     connection closed
# INFO:     2806:10a6:19:eb72:41c9:bc9b:f353:6037:0 - "WebSocket /stream?text=Gorillaz+es+una+banda+de+musica+podemos+meter+IA+&cfg=1.500&steps=5&voice=sp-Spk1_man" [accepted]
# INFO:     connection open
# WS handler exit
# Client connected, text='Gorillaz es una banda de musica podemos meter IA '
#
# Prefilled 381 tokens, current step (381 / 8192):   5%|▍         | 381/8192 [00:00<?, ?it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (386 / 8192):   5%|▍         | 386/8192 [00:00<00:00, 28416.69it/s]
# Prefilled 5 text tokens, generated 0 speech tokens, current step (386 / 8192):   5%|▍         | 387/8192 [00:00<03:34, 36.45it/s]
# Prefilled 5 text tokens, generated 1 speech tokens, current step (387 / 8192):   5%|▍         | 387/8192 [00:00<03:34, 36.45it/s]
# Prefilled 5 text tokens, generated 2 speech tokens, current step (388 / 8192):   5%|▍         | 388/8192 [00:00<03:34, 36.45it/s]
# Prefilled 5 text tokens, generated 3 speech tokens, current step (389 / 8192):   5%|▍         | 389/8192 [00:00<03:34, 36.45it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (390 / 8192):   5%|▍         | 390/8192 [00:00<03:34, 36.45it/s]
# Prefilled 5 text tokens, generated 4 speech tokens, current step (390 / 8192):   5%|▍         | 391/8192 [00:00<10:43, 12.12it/s]
# Prefilled 5 text tokens, generated 5 speech tokens, current step (391 / 8192):   5%|▍         | 391/8192 [00:00<10:43, 12.12it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (392 / 8192):   5%|▍         | 392/8192 [00:00<10:43, 12.12it/s]
# Prefilled 5 text tokens, generated 6 speech tokens, current step (392 / 8192):   5%|▍         | 397/8192 [00:00<07:34, 17.14it/s]
# Prefilled 10 text tokens, generated 6 speech tokens, current step (397 / 8192):   5%|▍         | 397/8192 [00:00<07:34, 17.14it/s]
# Prefilled 10 text tokens, generated 7 speech tokens, current step (398 / 8192):   5%|▍         | 398/8192 [00:01<07:34, 17.14it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (399 / 8192):   5%|▍         | 399/8192 [00:01<07:34, 17.14it/s]
# Prefilled 10 text tokens, generated 8 speech tokens, current step (399 / 8192):   5%|▍         | 400/8192 [00:01<10:00, 12.97it/s]
# Prefilled 10 text tokens, generated 9 speech tokens, current step (400 / 8192):   5%|▍         | 400/8192 [00:01<10:00, 12.97it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (401 / 8192):   5%|▍         | 401/8192 [00:01<10:00, 12.97it/s]
# Prefilled 10 text tokens, generated 10 speech tokens, current step (401 / 8192):   5%|▍         | 402/8192 [00:01<11:43, 11.07it/s]
# Prefilled 10 text tokens, generated 11 speech tokens, current step (402 / 8192):   5%|▍         | 402/8192 [00:01<11:43, 11.07it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (403 / 8192):   5%|▍         | 403/8192 [00:01<11:43, 11.07it/s]
# Prefilled 10 text tokens, generated 12 speech tokens, current step (403 / 8192):   5%|▍         | 406/8192 [00:01<10:03, 12.89it/s]
# Prefilled 13 text tokens, generated 12 speech tokens, current step (406 / 8192):   5%|▍         | 406/8192 [00:01<10:03, 12.89it/s]
# Prefilled 13 text tokens, generated 13 speech tokens, current step (407 / 8192):   5%|▍         | 407/8192 [00:01<10:03, 12.89it/s]
# Prefilled 13 text tokens, generated 13 speech tokens, current step (407 / 8192):   5%|▍         | 408/8192 [00:02<11:35, 11.20it/s]
# Prefilled 13 text tokens, generated 14 speech tokens, current step (408 / 8192):   5%|▍         | 408/8192 [00:02<11:35, 11.20it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (409 / 8192):   5%|▍         | 409/8192 [00:02<11:35, 11.20it/s]
# Prefilled 13 text tokens, generated 15 speech tokens, current step (409 / 8192):   5%|▌         | 410/8192 [00:02<12:23, 10.47it/s]
# Prefilled 13 text tokens, generated 16 speech tokens, current step (410 / 8192):   5%|▌         | 410/8192 [00:02<12:23, 10.47it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (411 / 8192):   5%|▌         | 411/8192 [00:02<12:23, 10.47it/s]
# Prefilled 13 text tokens, generated 17 speech tokens, current step (411 / 8192):   5%|▌         | 412/8192 [00:02<12:49, 10.11it/s]
# Prefilled 13 text tokens, generated 18 speech tokens, current step (412 / 8192):   5%|▌         | 412/8192 [00:02<12:49, 10.11it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (413 / 8192):   5%|▌         | 413/8192 [00:02<12:49, 10.11it/s]
# Prefilled 13 text tokens, generated 19 speech tokens, current step (413 / 8192):   5%|▌         | 414/8192 [00:02<12:57, 10.01it/s]
# Prefilled 13 text tokens, generated 20 speech tokens, current step (414 / 8192):   5%|▌         | 414/8192 [00:02<12:57, 10.01it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (415 / 8192):   5%|▌         | 415/8192 [00:02<12:57, 10.01it/s]
# Prefilled 13 text tokens, generated 21 speech tokens, current step (415 / 8192):   5%|▌         | 416/8192 [00:02<12:57, 10.00it/s]
# Prefilled 13 text tokens, generated 22 speech tokens, current step (416 / 8192):   5%|▌         | 416/8192 [00:02<12:57, 10.00it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (417 / 8192):   5%|▌         | 417/8192 [00:03<12:57, 10.00it/s]
# Prefilled 13 text tokens, generated 23 speech tokens, current step (417 / 8192):   5%|▌         | 418/8192 [00:03<13:03,  9.92it/s]
# Prefilled 13 text tokens, generated 24 speech tokens, current step (418 / 8192):   5%|▌         | 418/8192 [00:03<13:03,  9.92it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (419 / 8192):   5%|▌         | 419/8192 [00:03<13:03,  9.92it/s]
# Prefilled 13 text tokens, generated 25 speech tokens, current step (419 / 8192):   5%|▌         | 420/8192 [00:03<13:01,  9.95it/s]
# Prefilled 13 text tokens, generated 26 speech tokens, current step (420 / 8192):   5%|▌         | 420/8192 [00:03<13:01,  9.95it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (421 / 8192):   5%|▌         | 421/8192 [00:03<13:00,  9.95it/s]
# Prefilled 13 text tokens, generated 27 speech tokens, current step (421 / 8192):   5%|▌         | 422/8192 [00:03<13:08,  9.85it/s]
# Prefilled 13 text tokens, generated 28 speech tokens, current step (422 / 8192):   5%|▌         | 422/8192 [00:03<13:08,  9.85it/s]
# Prefilled 13 text tokens, generated 28 speech tokens, current step (422 / 8192):   5%|▌         | 423/8192 [00:03<13:08,  9.85it/s]
# Prefilled 13 text tokens, generated 29 speech tokens, current step (423 / 8192):   5%|▌         | 423/8192 [00:03<13:08,  9.85it/s]
# Prefilled 13 text tokens, generated 30 speech tokens, current step (424 / 8192):   5%|▌         | 424/8192 [00:03<13:08,  9.85it/s]
#
# INFO:     connection closed
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipython-input-3786657970.py in <cell line: 0>()
#      37         print(f"✅ Public URL: {public_url}\n");
#      38         public_url = None
# ---> 39     time.sleep(0.25)
#
# KeyboardInterrupt:
